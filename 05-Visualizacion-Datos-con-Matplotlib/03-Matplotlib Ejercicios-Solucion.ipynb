# %% [markdown]
# ___
#
# <a href='https://matplotlib.org/'> <img src='https://upload.wikimedia.org/wikipedia/en/thumb/5/56/Matplotlib_logo.svg/1280px-Matplotlib_logo.svg.png' /></a>
# ___
# # Ejercicios de Matplotlib
#
# ¡Bienvenido a los ejercicios para repasar matplotlib! Matplotlib puede ser difícil de entender al principio. Estos son gráficos relativamente simples, pero pueden ser difíciles si es la primera vez que se usa matplotlib
#
# Además, no te preocupes si encuentras frustrante la sintaxis de matplotlib, en realidad no la usaremos con tanta frecuencia a lo largo del curso, pasaremos a usar las capacidades de visualización integradas de seaborn y pandas. Pero, estos están construidos a partir de matplotlib, ¡por lo que aún es importante conocerlo!
#
# ***NOTA: TODOS LOS COMANDOS PARA TRAZAR UNA FIGURA DEBEN IR EN LA MISMA CELDA. SEPARARLOS EN MÚLTIPLES CÉLULAS PUEDE QUE NO SE MUESTRE NADA.***
#
# # Ejercicios
#
# Siga las instrucciones para recrear las gráficas con estos datos:
#
# ## Datos

# %%
pip install numpy

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rodyv\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Importe matplotlib.pyplot como plt y configure % matplotlib inline si está utilizando el cuaderno jupyter. ¿Qué comando usa si no está usando el cuaderno jupyter?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# **Siga estos pasos:**
#
# * ** Cree un objeto de figura llamado fig usando plt.figure () **
# * ** Use add_axes para agregar un eje al lienzo de la figura en [0,0,1,1]. Llame a este nuevo eje ax. **
# * ** Grafique (x, y) en esos ejes y establezca las etiquetas y títulos para que coincidan con el gráfico a continuación: **

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('titulo')
plt.plot(x,y)

# %% [markdown]
# ## Ejercicio 2
# ** Crea un objeto de figura y ponle dos ejes, ax1 y ax2. Ubicado en [0,0,1,1] y [0.2,0.5,.4,.4] respectivamente. **

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# ** Ahora grafique (x, y) en ambos ejes. Y llama a tu objeto figura para mostrarlo. **

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])
ax2.set_xlabel('X')
ax2.set_ylabel('Y')

#quitar los ejes y el cuadro
ax1.set_xticks([])
ax1.set_yticks([])
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['bottom'].set_visible(False) #perdon, creo xd

x = np.arange(0,100)
y = x*2

ax1.plot(x,y)
ax2.plot(x,y)
plt.show()

# %% [markdown]
# ## Ejercicio 3
#
# ** Cree la gráfica de abajo agregando dos ejes a un objeto figura en [0,0,1,1] y [0.2,0.5, .4, .4] **

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# ** Ahora use las matrices **x**, **y** y **z** para recrear el diagrama a continuación. Observe los xlimits y los límites y en la gráfica insertada: **

# %%
x = np.arange(0,100)
y = x*2

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

ax1.plot(x,y)

ax2.plot(x,y, 'orange')

ax2.set_title('zoom')

ax2.set_ylim([30, 50])
ax2.set_xlim([20, 22])
plt.show()

# %% [markdown]
# ## Ejercicio 4
#
# ** Utilice plt.subplots(nrows = 1, ncols = 2) para crear el gráfico a continuación. **

# %%
fig, axs = plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ** Ahora grafique (x,y) y (x,z) en los ejes. Juega con el ancho de línea y el estilo **

# %%
fig, axs = plt.subplots(nrows=1,ncols=2)

axs[0].plot(x,y, 'b', lw=3, ls='--')
axs[1].plot(x,x**2, 'r', lw=3, ls='-')

plt.tight_layout()
plt.show()

# %% [markdown]
# ** Ve si puedes cambiar el tamaño de la gráfica agregando el argumento figsize() en plt.subplots() (copiando y pegando tu código anterior). **

# %%
fig, axs = plt.subplots(nrows=1,ncols=2, figsize=(12,2))

axs[0].plot(x,y, 'b', lw=3, ls='-')
axs[1].plot(x,x**2, 'r', lw=3, ls='--')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Gran trabajo!
